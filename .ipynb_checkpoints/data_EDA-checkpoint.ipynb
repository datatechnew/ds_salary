# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data_cleaned.csv')

# %%
df.head(20)
#further analyze the job description
#Type of ownership encode
#revenue cleaning
# Out:
#                                             Job Title  \
# 0                                      Data Scientist
# 1                            Data Scientist Architect
# 2   Revit Expert / BIM Modeling Engineer - Concret...
# 3                            Bioinformatics Scientist
# 4                                       Data Engineer
# 5                              Risk Analytics Manager
# 6                               Senior Food Scientist
# 7   Medical Technologist (MT) / Medical Laboratory...
# 8                                       Data Engineer
# 9              Associate Director, Clinical Scientist
# 10                                      Data Engineer
# 11  Single B-Cell Antibody Discovery, Beacon Scien...
# 12                                          Scientist
# 13                                          Scientist
# 14                     Sr Data-Applied Scientist-PCCI
# 15       Senior Research Statistician- Data Scientist
# 16                     Market Research Data Scientist
# 17                                     Data Scientist
# 18                                      Data Engineer
# 19  Scientist/Research Associate-Metabolic Enginee...
#
#                 Salary Estimate  \
# 0   $78K-$133K (Glassdoor est.)
# 1   $78K-$133K (Glassdoor est.)
# 2   $78K-$133K (Glassdoor est.)
# 3   $78K-$133K (Glassdoor est.)
# 4   $78K-$133K (Glassdoor est.)
# 5   $78K-$133K (Glassdoor est.)
# 6   $78K-$133K (Glassdoor est.)
# 7   $78K-$133K (Glassdoor est.)
# 8   $78K-$133K (Glassdoor est.)
# 9   $78K-$133K (Glassdoor est.)
# 10  $78K-$133K (Glassdoor est.)
# 11  $78K-$133K (Glassdoor est.)
# 12  $78K-$133K (Glassdoor est.)
# 13  $78K-$133K (Glassdoor est.)
# 14  $78K-$133K (Glassdoor est.)
# 15  $78K-$133K (Glassdoor est.)
# 16  $78K-$133K (Glassdoor est.)
# 17  $78K-$133K (Glassdoor est.)
# 18  $78K-$133K (Glassdoor est.)
# 19  $78K-$133K (Glassdoor est.)
#
#                                       Job Description  Rating  \
# 0   Publishers Clearing House (PCH), located in Je...     3.3
# 1   This career opportunity is in our Minneapolis ...     4.2
# 2   We are seeking a professional familiar with co...    -1.0
# 3   Bioinformatics Scientist*\nEclipse is an RNA g...    -1.0
# 4   The Data Engineer will work with product owner...     2.7
# 5   Position summary: *\nThis Risk Analytics Manag...     4.4
# 6   Senior Food Scientist *\nWe’re looking for a P...     3.5
# 7   Sampson Regional Medical Center is hiring a Me...     2.2
# 8   Data Engineer\nU.S. citizenship is required fo...     3.0
# 9   Associate Director, Clinical Scientist*\nPrelu...    -1.0
# 10  About The Role:\n\nARC is searching for a Data...    -1.0
# 11  Abveris is Boston's premier antibody discovery...    -1.0
# 12  ArsenalBio’s mission is to develop efficacious...     5.0
# 13  Join us as we Rise to the Challenge\nAt KCI, w...     3.6
# 14  Looking for your next opportunity? If so, choo...     4.4
# 15  Acuity is seeking a Senior Research Statistici...     4.8
# 16  About Us\n\nAt GutCheck, we pioneered agile ma...     3.8
# 17  TACG is a driven Alaskan Native 8(a) professio...     4.5
# 18  Parsable gives frontline human workers a digit...     4.6
# 19  *Our company:\n*Conagen Inc. is a leader in cu...     2.5
#
#                                          Company Name  \
# 0                  Publishers Clearing House LLC\n3.3
# 1          Sullivan, Cotter and Associates, Inc.\n4.2
# 2                                   Palatial Concrete
# 3                              Eclipse BioInnovations
# 4                            Chenega Corporation\n2.7
# 5                     Cane Bay Partners VI, LLLP\n4.4
# 6                             R. Torre & Company\n3.5
# 7                Sampson Regional Medical Center\n2.2
# 8   Wisconsin Physicians Service Insurance Corpora...
# 9                   Prelude Therapeutics Incorporated
# 10               Airlines Reporting Corporation (ARC)
# 11                                   Abveris Antibody
# 12                                    ArsenalBio\n5.0
# 13                         KCI Technologies Inc.\n3.6
# 14  Parkland Center for Clinical Innovation (PCCI)...
# 15            Acuity, A Mutual Insurance Company\n4.8
# 16                                      GutCheck\n3.8
# 17                                     TACG, LLC\n4.5
# 18                                      Parsable\n4.6
# 19                               Conagen-Inc.com\n2.5
#
#                    Location                     Size  Founded  \
# 0               Jericho, NY    501 to 1000 Employees     1953
# 1           Minneapolis, MN     201 to 500 Employees     1992
# 2            Alexandria, VA                       -1       -1
# 3             San Diego, CA                       -1       -1
# 4           Springfield, VA  5001 to 10000 Employees     1974
# 5           Saint Croix, VI        1 to 50 Employees     2009
# 6         San Francisco, CA      51 to 200 Employees     1925
# 7               Clinton, NC    501 to 1000 Employees     1949
# 8               Madison, WI   1001 to 5000 Employees     1946
# 9            Wilmington, DE        1 to 50 Employees       -1
# 10            Arlington, VA                       -1       -1
# 11               Canton, MA                       -1       -1
# 12  South San Francisco, CA      51 to 200 Employees     2019
# 13               Sparks, MD   1001 to 5000 Employees     1988
# 14               Dallas, TX        1 to 50 Employees     2012
# 15            Sheboygan, WI   1001 to 5000 Employees     1925
# 16               Denver, CO      51 to 200 Employees     2009
# 17               Dayton, OH      51 to 200 Employees     2006
# 18                   Remote      51 to 200 Employees     2013
# 19          New Bedford, MA      51 to 200 Employees       -1
#
#          Type of ownership                                 Industry  ... aws  \
# 0        Company - Private                  Advertising & Marketing  ...   1
# 1        Company - Private                               Consulting  ...   0
# 2                       -1                                       -1  ...   0
# 3                       -1                                       -1  ...   1
# 4        Company - Private                      Aerospace & Defense  ...   1
# 5        Company - Private                               Consulting  ...   0
# 6        Company - Private            Food & Beverage Manufacturing  ...   0
# 7                 Hospital         Health Care Services & Hospitals  ...   0
# 8        Company - Private                       Insurance Carriers  ...   0
# 9         Company - Public                                       -1  ...   1
# 10                      -1                                       -1  ...   1
# 11                      -1                                       -1  ...   0
# 12       Company - Private                Biotech & Pharmaceuticals  ...   0
# 13       Company - Private     Architectural & Engineering Services  ...   0
# 14  Nonprofit Organization                              IT Services  ...   0
# 15       Company - Private                       Insurance Carriers  ...   0
# 16       Company - Private                   Research & Development  ...   0
# 17       Company - Private                               Consulting  ...   0
# 18       Company - Private  Enterprise Software & Network Solutions  ...   1
# 19       Company - Private                Biotech & Pharmaceuticals  ...   0
#
#    tableau spark State_New       Job_Title  Position_Level  desc_len  \
# 0        0     0        NY  data scientist         non-sen      2939
# 1        1     0        MN  data scientist         non-sen      5964
# 2        0     0        VA              na          senior       911
# 3        0     0        CA       scientist         non-sen      2945
# 4        0     0        VA   data engineer         non-sen      4474
# 5        0     0        VI         manager         non-sen      5255
# 6        0     1        CA       scientist          senior      4830
# 7        0     0        NC       scientist         non-sen      1465
# 8        0     0        WI   data engineer         non-sen      8608
# 9        0     0        DE        director         non-sen      5273
# 10       1     0        VA   data engineer         non-sen      5061
# 11       0     0        MA       scientist         non-sen      2901
# 12       0     0        CA       scientist         non-sen      3192
# 13       0     0        MD       scientist         non-sen      3160
# 14       0     0        TX       scientist          senior      4565
# 15       0     0        WI  data scientist          senior      1806
# 16       0     0        CO  data scientist         non-sen      3074
# 17       1     0        OH  data scientist         non-sen      4519
# 18       0     1    Remote   data engineer         non-sen      2103
# 19       0     0        MA       scientist         non-sen      3849
#
#     min_salary  max_salary  avg_salary
# 0           78         133       105.5
# 1           78         133       105.5
# 2           78         133       105.5
# 3           78         133       105.5
# 4           78         133       105.5
# 5           78         133       105.5
# 6           78         133       105.5
# 7           78         133       105.5
# 8           78         133       105.5
# 9           78         133       105.5
# 10          78         133       105.5
# 11          78         133       105.5
# 12          78         133       105.5
# 13          78         133       105.5
# 14          78         133       105.5
# 15          78         133       105.5
# 16          78         133       105.5
# 17          78         133       105.5
# 18          78         133       105.5
# 19          78         133       105.5
#
# [20 rows x 28 columns]

# %%
df.drop(columns = 'Company', inplace = True)

# %%
# change -1 to unknow
df['Ownership_Type']= df['Type of ownership'].apply(lambda x: "Unknown" if x == '-1' else x)
df['Ownership_Type'].value_counts()

# %%
df['age'].value_counts()
# Out:
# -1      492
#  11      99
#  8       99
#  21      90
#  54      80
#        ...
#  60       1
#  216      1
#  57       1
#  56       1
#  102      1
# Name: age, Length: 114, dtype: int64

# %%
#df['job_state']= df.job_state.apply(lambda x: x.strip() if x.strip().lower() != 'los angeles' else 'CA')

def myfunc(state):
    dic = {'United States' :' US','Georgia': ' GA','Utah' :' UT', 'California': ' CA', 'New Jersey': ' NJ'}
    for x in dic:
        if x in state.strip():
            return dic[x]
    return state

# %%
df['State_New'] = df['State'].apply(myfunc)

# %%
def job_title(title):
    keys = ['data scientist', 'data engineer','director', 'analyst','machine learning', 'manager','scientist']
    for title_name in keys:
      if title_name in title.strip().lower():
        return title_name
    return 'na'

# %%
df['Job_Title'] = df['Job Title'].apply(job_title)

# %%
df['Job_Title'].value_counts()
# Out:
# data scientist      1510
# machine learning     224
# analyst               97
# data engineer         76
# scientist             57
# na                    27
# manager                6
# director               3
# Name: Job_Title, dtype: int64

# %%
def seniority(title):
    if 'sr' in title.lower() or 'expert' in title.lower() or 'senior' in title.lower() or 'ap' in title.lower() or 'sr' in title.lower() or 'chef' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
            return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower() or 'entry' in title.lower():
        return 'jr'
    else:
        return 'non-sen'

# %%
df['Position_Level'] = df['Job Title'].apply(seniority)

# %%
df['Position_Level'].value_counts()
# Out:
# non-sen    1871
# senior      129
# Name: Position_Level, dtype: int64

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'salary', 'Company', 'State', 'age',
#        'SAS', 'python', 'aws', 'tableau', 'spark', 'State_New', 'Job_Title',
#        'Position_Level', 'desc_len', 'min_salary', 'max_salary', 'avg_salary'],
#       dtype='object')

# %%
# count the length of job description
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df['desc_len']
# Out:
# 0       2939
# 1       5964
# 2        911
# 3       2945
# 4       4474
#         ...
# 1995    2345
# 1996    1896
# 1997    3619
# 1998    2257
# 1999    3662
# Name: desc_len, Length: 2000, dtype: int64

# %%
df['min_salary'] = df['salary'].apply(lambda x: int(x.split('-')[0]))
df['max_salary'] = df['salary'].apply(lambda x: int(x.split('-')[1]))
df['avg_salary'] = (df.min_salary + df.max_salary)/2

# %%
df.Rating.hist()

# %%
df.avg_salary.hist()

# %%
df.age.hist()

# %%
df.desc_len.hist()

# %%
df.boxplot(column = ['age','avg_salary'])

# %%
df.boxplot(column = 'Rating')

# %%
df[['age','avg_salary','Rating','desc_len']].corr()
# Out:
#                  age  avg_salary    Rating  desc_len
# age         1.000000    0.194708  0.186169  0.208446
# avg_salary  0.194708    1.000000  0.074552  0.107870
# Rating      0.186169    0.074552  1.000000  0.059177
# desc_len    0.208446    0.107870  0.059177  1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['age','avg_salary','Rating','desc_len']].corr(),vmax=.3, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'salary', 'State', 'age', 'SAS',
#        'python', 'aws', 'tableau', 'spark', 'State_New', 'Job_Title',
#        'Position_Level', 'desc_len', 'min_salary', 'max_salary', 'avg_salary'],
#       dtype='object')

# %%
# change -1 to unknow
df['Ownership_Type']= df['Type of ownership'].apply(lambda x: "Unknown" if x == '-1' else x)
df['Size']= df['Size'].apply(lambda x: "Unknown" if x == '-1' else x)

# %%
new_df = df[['Rating', \
       'Size', 'Ownership_Type','Sector', 'Revenue','State_New','Job_Title','Position_Level',
             'SAS', 'python', 'aws', 'tableau', 'spark','State', 'Industry', 'age']]

# %%
plt.figure(figsize=(10,5))
for i in new_df.columns:
    new_num = new_df[i].value_counts()
    print("graph for %s: total = %d" % (i, len(new_num)))
    plt.figure(figsize=(10,5))
    bar =sns.barplot(x=new_num.index, y=new_num, data=new_df)
    bar.set_xticklabels(bar.get_xticklabels(), rotation=60)
    plt.show()
# Out:
# graph for Rating: total = 34
# graph for Size: total = 8
# graph for Ownership_Type: total = 12
# graph for Sector: total = 26
# graph for Revenue: total = 14
# graph for State_New: total = 43
# graph for Job_Title: total = 8
# graph for Position_Level: total = 2
# graph for SAS: total = 2
# graph for python: total = 2
# graph for aws: total = 2
# graph for tableau: total = 2
# graph for spark: total = 2
# graph for State: total = 47
# graph for Industry: total = 77
# graph for age: total = 114

# %%
plt.figure(figsize=(10,5))
for i in new_df[['State_New', 'Industry', 'age']].columns:
    new_num = new_df[i].value_counts()[:20]
    print("graph for %s: total = %d" % (i, len(new_num)))
    plt.figure(figsize=(10,5))
    bar =sns.barplot(x=new_num.index, y=new_num, data=new_df)
    bar.set_xticklabels(bar.get_xticklabels(), rotation=60)
    plt.show()
# Out:
# graph for State_New: total = 20
# graph for Industry: total = 20
# graph for age: total = 20

# %%
pd.pivot_table(df, index = 'Job_Title', values = 'avg_salary')
# Out:
#                   avg_salary
# Job_Title
# analyst           125.675258
# data engineer     118.690789
# data scientist     97.553974
# director          132.666667
# machine learning   94.118304
# manager           111.416667
# na                126.074074
# scientist         114.254386

# %%
pd.pivot_table(df, index = ['Job_Title','Position_Level'], values = 'avg_salary')
# Out:
#                                  avg_salary
# Job_Title        Position_Level
# analyst          non-sen         129.295775
#                  senior          115.788462
# data engineer    non-sen         119.745283
#                  senior          116.260870
# data scientist   non-sen          96.306396
#                  senior          129.946429
# director         non-sen         132.666667
# machine learning non-sen          93.939462
#                  senior          134.000000
# manager          non-sen         111.416667
# na               non-sen         127.952381
#                  senior          119.500000
# scientist        non-sen         117.350000
#                  senior          106.970588

# %%
pd.pivot_table(df, index = ['State','Job_Title'], values = 'avg_salary').sort_values('State', ascending = False)
# Out:
#                                 avg_salary
# State         Job_Title
# Utah          data scientist    134.000000
#               analyst           133.500000
# United States scientist         106.000000
#               na                101.500000
#               data scientist     92.303797
#               data engineer     133.000000
#               analyst           132.500000
# Remote        na                131.500000
#               manager            93.500000
#               data scientist    121.150000
#               data engineer     134.666667
#               analyst           100.750000
# New Jersey    data scientist    106.500000
# Georgia       data scientist     90.500000
# California    data scientist    121.000000
#  WY           analyst           105.500000
#  WV           data scientist    106.833333
#  WI           scientist          96.500000
#               na                 93.500000
#               data scientist    112.187500
#               data engineer     105.500000
#               analyst           117.750000
#  WA           scientist         149.000000
#               data scientist    106.142857
#               data engineer     107.500000
#               analyst           121.500000
#  VT           data scientist     93.000000
#  VI           manager           105.500000
#  VA           manager           115.000000
#               data engineer     105.038462
#               machine learning  124.000000
#               data scientist     94.269553
#               na                145.250000
#               scientist         122.800000
#  UT           machine learning  185.000000
#               data scientist     95.144444
#               data engineer     144.500000
#               analyst           144.250000
#  TX           data engineer     116.375000
#               analyst           107.500000
#               data scientist     95.566667
#               machine learning  133.500000
#               scientist         116.750000
#  TN           data scientist    129.500000
#               analyst            93.000000
#  SC           data scientist     74.000000
#               analyst           119.500000
#  RI           data engineer      90.250000
#  PA           data engineer     121.833333
#               analyst           128.166667
#               data scientist    107.307692
#  OR           data scientist    149.250000
#  OH           scientist         144.000000
#               data scientist    111.263158
#               analyst           107.500000
#  NY           scientist         149.000000
#               na                137.166667
#               machine learning   85.666667
#               data scientist     97.303846
#               data engineer     122.166667
#               analyst           149.666667
#  NM           data scientist    140.500000
#  NJ           analyst            94.166667
#               na                149.500000
#               director          107.500000
#               data scientist    127.333333
#  NH           data scientist    107.875000
#  NE           scientist         144.000000
#  NC           scientist         115.833333
#               data scientist    108.300000
#               analyst           111.666667
#  MS           scientist         134.000000
#  MO           data scientist    119.875000
#               data engineer     127.700000
#               analyst            82.500000
#  MN           na                149.000000
#               data scientist    105.500000
#               analyst           185.000000
#  MI           data scientist    114.687500
#               data engineer     149.500000
#  MD           data scientist     94.171429
#               analyst           128.300000
#               data engineer     101.125000
#               machine learning   90.500000
#               scientist         135.166667
#  MA           scientist         114.958333
#               na                125.666667
#               machine learning   91.266667
#               data scientist    106.133333
#               data engineer     106.666667
#               analyst           135.500000
#  KY           data scientist     97.000000
#  KS           machine learning  144.500000
#  IN           analyst           185.000000
#               scientist          79.500000
#               na                144.250000
#               data scientist    100.000000
#               data engineer     106.500000
#  IL           data engineer     106.500000
#               analyst           122.928571
#               data scientist     97.745763
#  ID           data scientist     93.000000
#               analyst           136.000000
#  GA           manager            65.500000
#               data scientist     92.297619
#               data engineer     149.000000
#               analyst            74.000000
#  FL           na                 97.000000
#               manager           144.500000
#               director          185.000000
#               data scientist     93.651163
#               analyst           134.833333
#  DE           director          105.500000
#  DC           data scientist     97.172414
#               analyst           185.000000
#               na                128.000000
#               scientist         149.500000
#  CT           data scientist    102.400000
#               data engineer     144.250000
#               analyst           127.500000
#  CO           data scientist    109.250000
#               data engineer     114.833333
#               analyst           143.800000
#  CA           scientist         106.911765
#               na                121.000000
#               machine learning   92.644000
#               data scientist    100.957721
#               data engineer     120.590909
#               analyst           116.214286
#  AZ           machine learning   90.250000
#               analyst           107.583333
#               data scientist    138.833333
#  AL           scientist         105.500000
#               data scientist     92.012195

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows', None)

# %%
pd.pivot_table(df, index = ['State','Job_Title'], values = 'avg_salary', aggfunc = 'count').sort_values('State', ascending = False)
# Out:
#                                 avg_salary
# State         Job_Title
# Utah          data scientist             1
#               analyst                    2
# United States scientist                  2
#               na                         1
#               data scientist            79
#               data engineer              4
#               analyst                    2
# Remote        na                         2
#               manager                    1
#               data scientist            10
#               data engineer              3
#               analyst                    2
# New Jersey    data scientist             1
# Georgia       data scientist            37
# California    data scientist             2
#  WY           analyst                    1
#  WV           data scientist             3
#  WI           scientist                  3
#               na                         1
#               data scientist             8
#               data engineer              1
#               analyst                    2
#  WA           scientist                  1
#               data scientist            14
#               data engineer              1
#               analyst                    2
#  VT           data scientist             1
#  VI           manager                    1
#  VA           manager                    1
#               data engineer             13
#               machine learning           7
#               data scientist           358
#               na                         2
#               scientist                  5
#  UT           machine learning           1
#               data scientist            45
#               data engineer              2
#               analyst                    2
#  TX           data engineer              4
#               analyst                    1
#               data scientist            60
#               machine learning           2
#               scientist                  2
#  TN           data scientist             2
#               analyst                    1
#  SC           data scientist             1
#               analyst                    7
#  RI           data engineer              2
#  PA           data engineer              3
#               analyst                    3
#               data scientist            13
#  OR           data scientist             2
#  OH           scientist                  1
#               data scientist            19
#               analyst                    1
#  NY           scientist                  1
#               na                         3
#               machine learning           3
#               data scientist           130
#               data engineer              6
#               analyst                    9
#  NM           data scientist             1
#  NJ           analyst                    3
#               na                         1
#               director                   1
#               data scientist             9
#  NH           data scientist             4
#  NE           scientist                  1
#  NC           scientist                  3
#               data scientist            10
#               analyst                    3
#  MS           scientist                  1
#  MO           data scientist             8
#               data engineer             10
#               analyst                    1
#  MN           na                         1
#               data scientist             1
#               analyst                    1
#  MI           data scientist             8
#               data engineer              1
#  MD           data scientist           105
#               analyst                    5
#               data engineer              4
#               machine learning          37
#               scientist                  3
#  MA           scientist                 12
#               na                         6
#               machine learning          45
#               data scientist            30
#               data engineer              3
#               analyst                    5
#  KY           data scientist             3
#  KS           machine learning           2
#  IN           analyst                    1
#               scientist                  3
#               na                         2
#               data scientist             2
#               data engineer              1
#  IL           data engineer              1
#               analyst                    7
#               data scientist            59
#  ID           data scientist             1
#               analyst                    2
#  GA           manager                    1
#               data scientist            84
#               data engineer              1
#               analyst                    1
#  FL           na                         3
#               manager                    2
#               director                   1
#               data scientist            43
#               analyst                    6
#  DE           director                   1
#  DC           data scientist            29
#               analyst                    1
#               na                         1
#               scientist                  1
#  CT           data scientist             5
#               data engineer              2
#               analyst                    1
#  CO           data scientist             6
#               data engineer              3
#               analyst                    5
#  CA           scientist                 17
#               na                         4
#               machine learning         125
#               data scientist           272
#               data engineer             11
#               analyst                   14
#  AZ           machine learning           2
#               analyst                    6
#               data scientist             3
#  AL           scientist                  1
#               data scientist            41

# %%
pd.pivot_table(df[df.Job_Title == 'data scientist'], index = 'State', values = 'avg_salary').sort_values('avg_salary', ascending = False)
# Out:
#                avg_salary
# State
#  OR            149.250000
#  NM            140.500000
#  AZ            138.833333
# Utah           134.000000
#  TN            129.500000
#  NJ            127.333333
# Remote         121.150000
# California     121.000000
#  MO            119.875000
#  MI            114.687500
#  WI            112.187500
#  OH            111.263158
#  CO            109.250000
#  NC            108.300000
#  NH            107.875000
#  PA            107.307692
#  WV            106.833333
# New Jersey     106.500000
#  WA            106.142857
#  MA            106.133333
#  MN            105.500000
#  CT            102.400000
#  CA            100.957721
#  IN            100.000000
#  IL             97.745763
#  NY             97.303846
#  DC             97.172414
#  KY             97.000000
#  TX             95.566667
#  UT             95.144444
#  VA             94.269553
#  MD             94.171429
#  FL             93.651163
#  VT             93.000000
#  ID             93.000000
# United States   92.303797
#  GA             92.297619
#  AL             92.012195
# Georgia         90.500000
#  SC             74.000000

# %%
df_pivots = df[['Rating', 'Industry', 'Sector', 'Job_Title','Revenue',  'python', 'spark', 'aws', 'tableau','SAS', 'Type of ownership','avg_salary']]

# %%
for i in df_pivots.columns[:-1]:
    print(i)
    print(pd.pivot_table(df_pivots,index =i, values = 'avg_salary').sort_values('avg_salary', ascending = False))
# Out:
# Rating
#         avg_salary
# Rating
#  2.4    149.000000
#  1.6    134.000000
#  2.6    131.600000
#  1.8    127.500000
#  4.8    123.000000
#  2.8    121.833333
#  3.9    117.023256
#  3.2    116.202128
#  3.5    114.648649
#  3.8    111.739796
#  2.9    109.812500
#  4.5    105.703704
#  4.3    104.246154
#  3.3    103.390625
#  3.7    103.048387
#  4.7    101.960938
#  2.1    101.500000
#  2.2    101.000000
#  4.4    100.900000
#  2.0    100.750000
#  5.0     99.147321
#  3.0     99.050000
#  4.0     98.992063
#  4.2     98.315068
#  3.4     97.347953
#  3.6     96.768519
#  4.9     96.255556
#  2.3     95.333333
#  4.1     94.805405
#  4.6     94.379032
# -1.0     94.229814
#  2.5     93.950000
#  2.7     93.000000
#  3.1     92.437500
# Industry
#                                          avg_salary
# Industry
# General Repair & Maintenance             185.000000
# Insurance Agencies & Brokerages          153.285714
# Sports & Recreation                      146.000000
# Stock Exchanges                          144.500000
# Telecommunications Manufacturing         143.250000
# Consumer Products Manufacturing          136.142857
# Legal                                    131.666667
# Education Training Services              131.500000
# Energy                                   131.333333
# Wholesale                                130.333333
# Food & Beverage Manufacturing            128.900000
# Home Centers & Hardware Stores           128.000000
# Oil & Gas Services                       127.500000
# Video Games                              125.166667
# Metal & Mineral Manufacturing            123.500000
# Internet                                 123.193548
# Telecommunications Services              122.666667
# Transportation Equipment Manufacturing   122.000000
# State & Regional Agencies                121.250000
# Research & Development                   121.153846
# Colleges & Universities                  120.681818
# Biotech & Pharmaceuticals                119.922222
# Car Rental                               119.500000
# Insurance Carriers                       117.222222
# Federal Agencies                         115.948276
# Sporting Goods Stores                    115.000000
# Logistics & Supply Chain                 115.000000
# Vehicle Dealers                          115.000000
# Automotive Parts & Accessories Stores    114.833333
# Architectural & Engineering Services     113.916667
# Banks & Credit Unions                    113.500000
# Department, Clothing, & Shoe Stores      112.166667
# TV Broadcast & Cable Networks            111.666667
# Lending                                  111.566667
# Utilities                                110.500000
# Social Assistance                        110.100000
# Health Care Services & Hospitals         109.838710
# Accounting                               108.600000
# Industrial Manufacturing                 107.600000
# Food Production                          107.500000
# Metals Brokers                           107.500000
# Membership Organizations                 107.500000
# Express Delivery Services                107.500000
# Timber Operations                        106.500000
# Hotels, Motels, & Resorts                106.500000
# K-12 Education                           105.500000
# Oil & Gas Exploration & Production       105.500000
# Food & Beverage Stores                   105.000000
# Casual Restaurants                       104.000000
# Cable, Internet & Telephone Providers    104.000000
# Brokerage Services                       103.000000
# Computer Hardware & Software             102.917219
# Real Estate                              102.833333
# Investment Banking & Asset Management    102.531250
# Beauty & Personal Accessories Stores     101.000000
# Advertising & Marketing                  100.917808
# News Outlet                              100.750000
# Other Retail Stores                      100.750000
# Financial Analytics & Research            99.800000
# Staffing & Outsourcing                    98.731132
# Enterprise Software & Network Solutions   97.131707
# Consulting                                95.865169
# Aerospace & Defense                       95.134921
# IT Services                               94.680000
# -1                                        94.649425
# Financial Transaction Processing          93.790698
# Electrical & Electronic Manufacturing     93.162791
# Rail                                      93.000000
# Building & Personnel Services             90.500000
# Health, Beauty, & Fitness                 90.500000
# Chemical Manufacturing                    89.000000
# Grantmaking Foundations                   86.000000
# Transportation Management                 75.250000
# Farm Support Services                     75.250000
# Security Services                         74.000000
# Gas Stations                              74.000000
# Publishing                                68.000000
# Sector
#                                     avg_salary
# Sector
# Construction, Repair & Maintenance  185.000000
# Arts, Entertainment & Recreation    146.000000
# Insurance                           124.647059
# Telecommunications                  123.214286
# Education                           121.441176
# Biotech & Pharmaceuticals           119.922222
# Oil, Gas, Energy & Utilities        117.950000
# Accounting & Legal                  117.250000
# Government                          116.290323
# Media                               115.400000
# Travel & Tourism                    113.000000
# Health Care                         109.838710
# Retail                              108.694444
# Mining & Metals                     107.500000
# Restaurants, Bars & Food Services   104.000000
# Manufacturing                       103.563380
# Non-Profit                          103.214286
# Real Estate                         102.833333
# Finance                             102.801282
# Information Technology               98.508734
# Business Services                    98.267943
# Aerospace & Defense                  95.134921
# -1                                   94.649425
# Transportation & Logistics           93.200000
# Agriculture & Forestry               91.125000
# Consumer Services                    90.500000
# Job_Title
#                   avg_salary
# Job_Title
# director          132.666667
# na                126.074074
# analyst           125.675258
# data engineer     118.690789
# scientist         114.254386
# manager           111.416667
# data scientist     97.553974
# machine learning   94.118304
# Revenue
#                                   avg_salary
# Revenue
# $5 to $10 billion (USD)           121.190476
# $50 to $100 million (USD)         117.750000
# $1 to $2 billion (USD)            103.757895
# $100 to $500 million (USD)        102.258065
# $10+ billion (USD)                101.982394
# $500 million to $1 billion (USD)  101.677632
# $10 to $25 million (USD)          101.394161
# Unknown / Non-Applicable          101.250951
# $25 to $50 million (USD)          101.227273
# $2 to $5 billion (USD)             96.995690
# $1 to $5 million (USD)             96.119718
# Less than $1 million (USD)         94.782772
# -1                                 94.267241
# $5 to $10 million (USD)            93.655340
# python
#         avg_salary
# python
# 0       101.307220
# 1        99.801334
# spark
#        avg_salary
# spark
# 0      100.623841
# 1       99.267347
# aws
#      avg_salary
# aws
# 0    100.295218
# 1    100.281867
# tableau
#          avg_salary
# tableau
# 1        101.834140
# 0         99.890044
# SAS
#      avg_salary
# SAS
# 1    100.751712
# 0    100.212822
# Type of ownership
#                                 avg_salary
# Type of ownership
# Other Organization              128.700000
# Private Practice / Firm         126.500000
# College / University            121.937500
# Hospital                        117.875000
# Nonprofit Organization          117.089552
# Government                      114.529412
# Self-employed                   106.500000
# Company - Public                101.066351
# Company - Private                99.481405
# Subsidiary or Business Segment   98.394958
# Unknown                          95.625000
# -1                               94.267241
# Contract                         91.500000

# %%
pd.pivot_table(df_pivots, index = 'Revenue', columns = 'python', values = 'avg_salary', aggfunc = 'count')
# Out:
# python                              0    1
# Revenue
# $1 to $2 billion (USD)             20   75
# $1 to $5 million (USD)              6   65
# $10 to $25 million (USD)           91   46
# $10+ billion (USD)                 93   49
# $100 to $500 million (USD)        118   99
# $2 to $5 billion (USD)             11  105
# $25 to $50 million (USD)           15  106
# $5 to $10 billion (USD)             9   12
# $5 to $10 million (USD)            84   19
# $50 to $100 million (USD)          17   33
# $500 million to $1 billion (USD)   14   62
# -1                                 10   48
# Less than $1 million (USD)         17  250
# Unknown / Non-Applicable          146  380

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      85                 try:
# ---> 86                     root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#      87                 except LookupError:
#
# ~\anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     700     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 701     raise LookupError(resource_not_found)
#     702
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords.zip/stopwords/
#
#   Searched in:
#     - 'C:\\Users\\Administrator/nltk_data'
#     - 'C:\\Users\\Administrator\\anaconda3\\nltk_data'
#     - 'C:\\Users\\Administrator\\anaconda3\\share\\nltk_data'
#     - 'C:\\Users\\Administrator\\anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\Administrator\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# <ipython-input-295-c77528177ed4> in <module>
#      12
#      13
# ---> 14 words_filtered = punctuation_stop(words)
#      15
#      16 text = " ".join([ele for ele in words_filtered])
#
# <ipython-input-295-c77528177ed4> in punctuation_stop(text)
#       4     """remove punctuation and stop words"""
#       5     filtered = []
# ----> 6     stop_words = set(stopwords.words('english'))
#       7     word_tokens = word_tokenize(text)
#       8     for w in word_tokens:
#
# ~\anaconda3\lib\site-packages\nltk\corpus\util.py in __getattr__(self, attr)
#     121             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#     122
# --> 123         self.__load()
#     124         # This looks circular, but its not, since __load() changes our
#     125         # __class__ to something new:
#
# ~\anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      86                     root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#      87                 except LookupError:
# ---> 88                     raise e
#      89
#      90         # Load the corpus.
#
# ~\anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      81         else:
#      82             try:
# ---> 83                 root = nltk.data.find('{}/{}'.format(self.subdir, self.__name))
#      84             except LookupError as e:
#      85                 try:
#
# ~\anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     699     sep = '*' * 70
#     700     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 701     raise LookupError(resource_not_found)
#     702
#     703
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords
#
#   Searched in:
#     - 'C:\\Users\\Administrator/nltk_data'
#     - 'C:\\Users\\Administrator\\anaconda3\\nltk_data'
#     - 'C:\\Users\\Administrator\\anaconda3\\share\\nltk_data'
#     - 'C:\\Users\\Administrator\\anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\Administrator\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
df.to_csv('eda_data.csv')

# %%
''' 
#####some useful trick#####
import re
regex = '\d+'             
    
match = re.findall(regex, string)  
print(match)  


df['Company'] = df.apply(lambda x: x['Company Name'] if x['Rating'] < 1 else x['Company Name'][:-3], axis = 1)
remove the \n from company name
df['Company'] = df.Company.apply(lambda x: x.replace('\n', ''))

pd.options.display.max_rows
pd.set_option('display.max_rows', None)

'''
